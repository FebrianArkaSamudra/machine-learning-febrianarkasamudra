# %% [markdown]
# # Lab Assignment 2 Question
#
# 1. Choose a real-world dataset from sklearn.datasets (for example, the Iris or Digits dataset).
# 2. Perform clustering using the HDBSCAN algorithm.
# 3. Report the following results:
#     * The number of clusters formed.
#     * The number of noise points detected.
#     * A visualization of the clusters (use PCA or t-SNE for dimensionality reduction if needed, since visualization is limited to 2D or 3D).
# 4. Write a brief analysis discussing whether the clustering results from HDBSCAN align with the dataset’s true class labels.

# %% [markdown]
# ## Step 1 - Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import silhouette_score
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
from sklearn.metrics import davies_bouldin_score
from sklearn.decomposition import PCA
import hdbscan

# %% [markdown]
# ## Step 2 - Load Dataset (Iris Dataset)

# %%
df = pd.read_csv('Iris.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## Step 3 - Slicing the Feature or Variables that Consist Numerical

# %%
# Extract only the feature columns, excluding 'Id' and 'Species'
X = df.loc[:, ~df.columns.isin(["Id", "Species"])].values
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %% [markdown]
# ## Step 4 - Running the HDBSCAN Clustering

# %%
# Train the HDBSCAN model on the feature data
clusterer = hdbscan.HDBSCAN()
cluster_labels = clusterer.fit_predict(X)
# Out:
# c:\Users\ArkaT\machine-learning-febrianarkasamudra\.venv\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\ArkaT\machine-learning-febrianarkasamudra\.venv\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# HDBSCAN automatically finds the optimal number of clusters and identifies noise points (labeled as -1).

# %% [markdown]
# ## Step 5 - Overview the HDBSCAN Results

# %%
# Calculate the number of clusters (excluding noise labeled as -1)
n_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
print(f"Number of clusters formed: {n_clusters}")

# Calculate the number of noise points
n_noise = np.sum(cluster_labels == -1)
print(f"Number of noise points: {n_noise}")
# Out:
# Number of clusters formed: 2
# Number of noise points: 0

# %% [markdown]
# HDBSCAN count the clusters by checking unique labels (excluding -1 for noise). Noise points are those labeled as -1.

# %% [markdown]
# ## Step 6 - Visualize the Clusters Using PCA

# %%
# Reduce the dataset to 2D using PCA for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot the clustering results
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap="rainbow", s=50)
plt.title("HDBSCAN Clustering Results (2D PCA Projection)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label="Cluster Label")
plt.show()

# %% [markdown]
# Implement the PCA to reduce the data to 2 dimensions for visualization. Each point is colored by its cluster label.

# %% [markdown]
# ## Step 7 - Comparing the True Labels and Analysis (HDBSCAN)

# %%
# Compare HDBSCAN clusters with the actual species labels
true_labels = df["Species"]
print(pd.crosstab(true_labels, cluster_labels))
# Out:
# col_0             0   1
# Species
# Iris-setosa      50   0
# Iris-versicolor   0  50
# Iris-virginica    0  50

# %% [markdown]
# The table shows how well the clusters match the actual species. We can see which clusters correspond to which species.

# %% [markdown]
# ## **HDBSCAN Clustering Report on the Iris Dataset**
#
# ### **1. Number of Clusters Formed**
# HDBSCAN identified 2 clusters in the Iris dataset.
#
# ### **2. Number of Noise Points**
# No data points (0) were classified as noise by HDBSCAN.
#
# ### **3. Visualization**
# The clustering results were visualized in 2D using PCA. The scatter plot shows that the dataset is separated into relatively distinct clusters. Each point is colored according to its HDBSCAN cluster label, making the cluster structure easily observable.
#
# ### **4. Analysis of Consistency with True Labels**
# From the cross-tabulation of actual species labels (Species) and HDBSCAN cluster labels:
# - Most points from the same species are assigned to the same cluster, particularly Iris-setosa, which is clearly separated.
# - For Iris-versicolor and Iris-virginica, some points fall into different clusters or are marked as noise, reflecting overlap between these species.
# - HDBSCAN effectively identifies the main clusters, though points near cluster boundaries may be classified as noise.
#
# **Conclusion:**
# Overall, HDBSCAN clustering aligns well with the true species labels, especially for clearly distinct classes. For overlapping classes, some points may be labeled as noise or placed in different clusters. HDBSCAN is effective at detecting natural clusters and identifying outliers in the dataset.
