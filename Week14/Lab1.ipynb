# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Training Data Preprocessing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('D:\\machine-learning-febrianarkasamudra\\Week14\\dataset\\dataset\\training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ## Testing Data Preprocessing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('D:\\machine-learning-febrianarkasamudra\\Week14\\dataset\\dataset\\test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# # Construction of the CNN Model

# %% [markdown]
# ## CNN Model Initialization

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ## Creation of Convolutional Layer 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# c:\Users\ArkaT\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Creation of Pooling Layer 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ## Creation of Convolutional Layer 2 and pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ## Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ## Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ## Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Compile the CNN Model

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # Fit the CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.5850 - loss: 0.6731 - val_accuracy: 0.5750 - val_loss: 0.7296
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 103ms/step - accuracy: 0.6561 - loss: 0.6363 - val_accuracy: 0.6205 - val_loss: 0.6418
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 115ms/step - accuracy: 0.6736 - loss: 0.6021 - val_accuracy: 0.7070 - val_loss: 0.5804
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 101ms/step - accuracy: 0.7011 - loss: 0.5730 - val_accuracy: 0.7170 - val_loss: 0.5625
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 100ms/step - accuracy: 0.7299 - loss: 0.5375 - val_accuracy: 0.7420 - val_loss: 0.5352
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 99ms/step - accuracy: 0.7487 - loss: 0.5140 - val_accuracy: 0.7100 - val_loss: 0.5710
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 99ms/step - accuracy: 0.7614 - loss: 0.4878 - val_accuracy: 0.7535 - val_loss: 0.5073
# Epoch 8/25
# ...

# %% [markdown]
# # Prediction with a Single Image

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('D:\machine-learning-febrianarkasamudra\Week14\dataset\dataset\single_prediction\cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step

# %%
print("Prediction:", prediction)
# Out:
# Prediction: dog
